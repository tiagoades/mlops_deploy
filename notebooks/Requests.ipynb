# %%
import requests

# %%
url = 'http://127.0.0.1:5000/cotacao/'

# %%
dados = {
    "tamanho":100,
    "ano":2001,
    "garagem":2
}

# %%
auth = requests.auth.HTTPBasicAuth('MLOps','MLOps')

# %%
response = requests.post(url, json=dados, auth=auth)

# %%
response.json()
# Out:
# {'preco': 174836.4043938208}
