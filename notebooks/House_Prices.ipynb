# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f89a7b4-37d0-4753-8bee-00784fb985ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f89a7b4-37d0-4753-8bee-00784fb985ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving casas.csv to casas.csv

# %%
import io
import pandas as pd

df = pd.read_csv(io.BytesIO(uploaded['casas.csv']))

df.head()
# Out:
#    tamanho   ano  garagem   preco
# 0    159.0  2003        2  208500
# 1    117.0  1976        2  181500
# 2    166.0  2001        2  223500
# 3    160.0  1915        3  140000
# 4    204.0  2000        3  250000

# %%
#colunas  = ['tamanho', 'preco']
#df = df[colunas]

#df.head()

# %%
x = df.drop('preco', axis=1)
y = df['preco']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train.head()
# Out:
#       tamanho   ano  garagem
# 135     156.0  1970        2
# 1452    100.0  2005        2
# 762     144.0  2009        2
# 932     177.0  2006        3
# 435     154.0  1996        2

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()
modelo.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# modelo.intercept_

# %%
modelo.predict([[120, 2001, 2]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([191436.53503831])

# %%
{
    "tamanho":120,
    "ano":2001,
    "garagem":2
}
# Out:
# {'ano': 2001, 'garagem': 2, 'tamanho': 120}

# %%
import pickle

# %%
pickle.dump(modelo, open('modelo.sav', 'wb'))

# %%
files.download('modelo.sav')

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'
